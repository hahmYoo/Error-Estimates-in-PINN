# %%
import matplotlib.pyplot as plt
import matplotlib_inline.backend_inline
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import scipy.integrate as integrate
from tqdm.auto import tqdm

matplotlib_inline.backend_inline.set_matplotlib_formats("png2x")
plt.style.use("default")
plt.rcParams.update(
    {
        "figure.constrained_layout.use": True,
        "figure.facecolor": "white",
    }
)

n_dense_points = 201

# %%
def Separable(t, y):
    """Exact equation y' = (3*t**2+4*t+2)/(2y-2)
    """
    return (3*t**2+4*t+2)/(2*y-2)

def Separable_exact(t, y0):
    return 1.0-np.sqrt(t**3+2.0*t**2+2.0*t+(y0-1)**2)

# %%
domain = (0, 1)
t0 = 0.0
y0 = -1.0

t_dense = np.linspace(*domain, n_dense_points)

# %%
class MLP(nn.Module):
    def __init__(self, *features, activation=nn.Tanh):
        super().__init__()

        layers = []
        for in_features, out_features in zip(features, features[1:]):
            layers.append(nn.Linear(in_features, out_features))
            layers.append(activation())
        self.network = nn.Sequential(*layers[:-1])

    def forward(self, x):
        return self.network(x)

# %%
def grad(outputs, inputs):
    return torch.autograd.grad(outputs.sum(), inputs, create_graph=True)[0]

# %%
torch.manual_seed(78)
model = MLP(1, 16, 32, 1)
t0=0.0
y0=-1.0

# %%
batch_size = 10000
n_epochs = 1_000
print_interval = n_epochs // 10
learning_rate = 0.01

optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer=optimizer,
                                        lr_lambda=lambda epoch: 0.98 ** epoch,
                                        last_epoch=-1,
                                        verbose=False)

loss_history = []
realloss_history=[]
for epoch in tqdm(range(n_epochs)):
    optimizer.zero_grad()

    # 무작위 t 생성 후 y 계산
    t = torch.empty(batch_size, 1).uniform_(*domain).requires_grad_()
    y = model(t)
    y_e=1.0-torch.sqrt(t**3+2.0*t**2+2.0*t+4)
    y_t = grad(y, t)

    # Loss
    loss_de = F.mse_loss( (3*t**2+4*t+2)/(2*y-2)- y_t, torch.zeros_like(y_t))
    loss_ic = F.mse_loss(model(torch.tensor([[t0]])), torch.tensor([[y0]]))
    loss = loss_de + loss_ic
    realloss=F.mse_loss(y-y_e, torch.zeros_like(y))
    # Backprop
    loss.backward()
    optimizer.step()

    loss_history.append(loss.item())
    realloss_history.append(realloss.item())
    if epoch % print_interval == 0:
        print(f"{epoch = }, loss_de = {loss_de.item():.4f}, loss_ic = {loss_ic.item():.4f}, loss = {loss.item():.4f}")
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# epoch = 0, loss_de = 18.3423, loss_ic = 1.3926, loss = 19.7349
# epoch = 100, loss_de = 0.1073, loss_ic = 0.0004, loss = 0.1077
# epoch = 200, loss_de = 0.0022, loss_ic = 0.0000, loss = 0.0022
# epoch = 300, loss_de = 0.0019, loss_ic = 0.0000, loss = 0.0019
# epoch = 400, loss_de = 0.0015, loss_ic = 0.0000, loss = 0.0015
# epoch = 500, loss_de = 0.0012, loss_ic = 0.0000, loss = 0.0012
# epoch = 600, loss_de = 0.0009, loss_ic = 0.0000, loss = 0.0009
# epoch = 700, loss_de = 0.0007, loss_ic = 0.0000, loss = 0.0007
# epoch = 800, loss_de = 0.0006, loss_ic = 0.0000, loss = 0.0006
# epoch = 900, loss_de = 0.0004, loss_ic = 0.0000, loss = 0.0004

# %%
fig, ax = plt.subplots()
ax.plot(loss_history,"b", label = "training loss")
ax.plot(realloss_history,"r",alpha=0.5, label = "error")
ax.set(
    yscale="log",
    xlabel="Epoch",
    ylabel="log scale",
    title = "PINN I"
)
ax.legend()
ax.grid()
ax.spines[["top", "right", "left"]].set_visible(False)
pass

# %%
X=np.array(loss_history)
Y=np.array(realloss_history)

# %%
import matplotlib.transforms as transforms

fig, ax = plt.subplots()
ax.plot(Y/X,"b")
plt.axhline(3, 0, 1, color='black', linestyle='--', linewidth=1)
trans = transforms.blended_transform_factory(ax.get_yticklabels()[0].get_transform(), ax.transData)
ax.text(0, 3, "{:d}".format(3), color="black", transform=trans, ha="right", va="center")
ax.set(
    yscale="log",    ylabel="log scale",    xlabel="Epoch",
    title=r"$\frac{error}{loss}$"
)
ax.grid()
ax.spines[["top", "right", "left"]].set_visible(False)
pass

# %%
torch.manual_seed(78)
model = MLP(1, 16, 32, 1)

# %%
batch_size = 10000
n_epochs = 1_000
print_interval = n_epochs // 10
learning_rate = 0.01

optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer=optimizer,
                                        lr_lambda=lambda epoch: 0.98 ** epoch,
                                        last_epoch=-1,
                                        verbose=False)

loss_history = []
realloss_history=[]
for epoch in tqdm(range(n_epochs)):
    optimizer.zero_grad()

    # 무작위 t 생성 후 y 계산
    t = torch.empty(batch_size, 1).uniform_(*domain).requires_grad_()
    y = t*model(t)-1
    y_e= 1.0-torch.sqrt(t**3+2.0*t**2+2.0*t+4)
    y_t = grad(y, t)

    # Loss
    loss_de = F.mse_loss((3*t**2+4*t+2)/(2*y-2) - y_t, torch.zeros_like(y_t))
    loss = loss_de
    realloss=F.mse_loss(y-y_e, torch.zeros_like(y))
    # Backprop
    loss.backward()
    optimizer.step()
    scheduler.step()

    loss_history.append(loss.item())
    realloss_history.append(realloss.item())
    if epoch % print_interval == 0:
        print(f"{epoch = }, loss_de = {loss_de.item():.4f}, loss = {loss.item():.4f}")
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# epoch = 0, loss_de = 3.8223, loss = 3.8223
# epoch = 100, loss_de = 0.0021, loss = 0.0021
# epoch = 200, loss_de = 0.0019, loss = 0.0019
# epoch = 300, loss_de = 0.0019, loss = 0.0019
# epoch = 400, loss_de = 0.0018, loss = 0.0018
# epoch = 500, loss_de = 0.0018, loss = 0.0018
# epoch = 600, loss_de = 0.0018, loss = 0.0018
# epoch = 700, loss_de = 0.0018, loss = 0.0018
# epoch = 800, loss_de = 0.0018, loss = 0.0018
# epoch = 900, loss_de = 0.0018, loss = 0.0018

# %%
fig, ax = plt.subplots()
ax.plot(loss_history,"b", label = "training loss")
ax.plot(realloss_history,"r",alpha=0.5, label = "error")
ax.set(
    yscale="log",
    xlabel="Epoch",
    ylabel="log scale",
    title = "PINN II"
)
ax.legend()
ax.grid()
ax.spines[["top", "right", "left"]].set_visible(False)
pass

# %%
X=np.array(loss_history)
Y=np.array(realloss_history)

# %%
fig, ax = plt.subplots()
ax.plot(Y/X,"b")
plt.axhline(2, 0, 1, color='black', linestyle='--', linewidth=1)
trans = transforms.blended_transform_factory(ax.get_yticklabels()[0].get_transform(), ax.transData)
ax.text(0, 2, "{:d}".format(2), color="black", transform=trans, ha="right", va="center")
ax.set(
    yscale="log",    ylabel="log scale",    xlabel="Epoch",
    title=r"$\frac{error}{loss}$"
)
ax.grid()
ax.spines[["top", "right", "left"]].set_visible(False)
pass
